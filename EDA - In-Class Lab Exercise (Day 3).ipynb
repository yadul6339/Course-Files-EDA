# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame as df
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
ad=pd.read_csv('adult.csv')
ad.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.scatterplot(data=ad,x='age',y='hours.per.week')
plt.show()

# %% [raw]
# # In this plot we can see that age between 20 and 65 have the highest working hours but after age of 65 working hours
# decreases gradually.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=ad,x='education.num',y='capital.gain')
plt.show()

# %% [raw]
# # Education qualification in between 12 to 16 have the highest capital gain. Left all the educational qualifications
# have not much impact on capital gain.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=ad,x='hours.per.week',y='capital.gain')
plt.show()

# %% [raw]
# # Individuals who have worked from 20 to 80 hours have the highest capital gain at the outliers.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
ad.groupby(ad['age']).mean()['hours.per.week'].plot(kind='line')
plt.show()

# %% [raw]
# # Here in the plot we can see that after the age of 50 years the working hours decreases upto the age of 85 and there
# is a straight decrease of working hour at the age of 85.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
ad.groupby(ad['age']).mean()['capital.loss'].plot(kind='line')
plt.show()

# %% [raw]
# # In this plot we can see that there is a huge capital loss raising from the age 85 to 90.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.regplot(data=ad,x='capital.gain',y='age')
plt.show()

# %% [raw]
# # There is no negative relation between capital gain and age as per the plot.

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
ad.groupby(ad['income']).mean()['age'].plot(kind='bar')
plt.show()

# %% [raw]
# # In this plot we can see the average age for income less than 50k is ~35 whereas for income greater than 50k, the average
# age is ~40+.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.violinplot(data=ad,x='sex',y='hours.per.week')
plt.show()

# %% [raw]
# # Here we can see that males have more work after 40 hours of work comparing to females as the thickness of plot shows.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=ad,x='income',y='education.num')
plt.show()

# %% [raw]
# # Those who have education qualification below  9 have income less than 50k and above 9 have income higher than 50k.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
ad.groupby('sex').mean()['age'].plot(kind='bar')
plt.show()

# %% [raw]
# # Average age of males and females are between 35 to 40.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.violinplot(data=ad,x='income',y='hours.per.week')
plt.show()

# %% [raw]
# # Those who work for 40 hours per week are highly seen in the income level <=50k comparing with income level >50k.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.violinplot(data=ad,x='race',y='age',hue='sex',split=True)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
fig,axes=plt.subplots(1,2,figsize=(15,8))
sns.barplot(data=ad,x='workclass',y='hours.per.week',ax=axes[0])
plt.xticks(rotation=90)
sns.boxplot(data=ad,x='workclass',y='hours.per.week',ax=axes[1])
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# # Self employed individuals have more working hours and never worked individuals have less working hours.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.boxplot(data=ad,x='sex',y='fnlwgt')
plt.show()

# %% [raw]
# # Weightage based on demographic characteristics by both the gender is between the range from 175000 to 200000.

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(pd.crosstab(index=ad['sex'],columns=ad['income']).apply(lambda x: x/(x.sum()),axis=1))
pd.crosstab(index=ad['sex'],columns=ad['income']).apply(lambda x: x/(x.sum()),axis=1).plot(kind='bar')
plt.show()
# Out:
# income     <=50K      >50K
# sex
# Female  0.890539  0.109461
# Male    0.694263  0.305737

# %% [raw]
# # Male employees works for higher income and Female employees works more for lower income.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
pd.crosstab(index=ad['race'],columns=ad['income']).plot(kind='bar',stacked=True)
plt.show()

# %% [raw]
# # White race employees works for both higher income and lower income.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=ad,x='occupation',hue='sex')
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# # According to the plot there are no females in Armed Forces, so that we can consider Armed Forces as male profession.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=ad,x='workclass',hue='income')
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# # Private class employees works for both higher income and lower income.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.countplot(data=ad,hue='income',x='marital.status')
plt.xticks(rotation=90)
plt.show()

# %% [raw]
# # Never married employees have the income less than 50k and Married civ spouse have the income greater than 50k.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))
pd.crosstab(index=ad['occupation'],columns=ad['income']).plot(kind='bar',stacked=True)
plt.show()

# %% [raw]
# # According to the plot for Admin clerikal job many employees are working for income less than 50k.
#  Similarly for the job Exec managerial many employees are working for income higher than 50k.
